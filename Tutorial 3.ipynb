# %% [markdown]
# # Tutorial 3 - Data Importing and Cleaning

# %% [markdown]
# Packages to install:
# * `pandas`
# * `matplotlib`
#
# How to install:
# Running `!pip install pandas` and  `!pip install matplotlib` in one of the cell, and wait for the installation.

# %% [markdown]
# ### Question 1
#
# Based on the data below, do the following:
#
# 1. Import necessary libraries
# 2. Load the data into a dataframe
# 3. Convert 'Date' column to datetime format
# 4. Check for missing values (use `isna`/`isnull` function)
# 5. Check for duplicates (use `duplicated` function)
# 6. Remove duplicates if any
# 7. Summary statistics (use the pandas `describe` function)
# 8. Calculate total sales amount
# 9. Save Cleaned Data

# %% [markdown]
# Data is below:
#
# ```
# data = {
#     'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
#     'Product': ['A', 'B', 'A', 'C', 'B'],
#     'Price': [10, 20, 15, 25, 30],
#     'Quantity': [100, 150, 200, 120, 180]
# }
# ```

# %%
data = {
    'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05'],
    'Product': ['A', 'B', 'A', 'C', 'B'],
    'Price': [10, 20, 15, 25, 30],
    'Quantity': [100, 150, 200, 120, 180]
}
import pandas as pd
df = pd.DataFrame(data)
print(df)
df.Date = pd.to_datetime(df.Date)
# Out:
#          Date Product  Price  Quantity
# 0  2024-01-01       A     10       100
# 1  2024-01-02       B     20       150
# 2  2024-01-03       A     15       200
# 3  2024-01-04       C     25       120
# 4  2024-01-05       B     30       180

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
print(df.isna())
# Out:
#     Date  Product  Price  Quantity
# 0  False    False  False     False
# 1  False    False  False     False
# 2  False    False  False     False
# 3  False    False  False     False
# 4  False    False  False     False

# %%
stats = df.describe()
print(stats)
# Out:
#                       Date      Price    Quantity
# count                    5   5.000000    5.000000
# mean   2024-01-03 00:00:00  20.000000  150.000000
# min    2024-01-01 00:00:00  10.000000  100.000000
# 25%    2024-01-02 00:00:00  15.000000  120.000000
# 50%    2024-01-03 00:00:00  20.000000  150.000000
# 75%    2024-01-04 00:00:00  25.000000  180.000000
# max    2024-01-05 00:00:00  30.000000  200.000000
# std                    NaN   7.905694   41.231056

# %%
df['Total_Sales'] = df['Price'] * df['Quantity']
df.to_csv('clean_data.csv', index=False)

# %% [markdown]
# ### Question 2

# %% [markdown]
# Data cleaning using a CSV file containing information about online retail transactions.
# Based on the data, do the following:
#
# 1. Save the provided data as `online_retail.csv` in the same directory as your Python script.
# 2. Import necessary libraries
# 3. Load the data from CSV
# 4. Check for missing values
# 5. Remove rows with missing values
# 6. Convert 'InvoiceDate' column to datetime format
# 7. Calculate the total transactions per country (using `groupby` function)
# 8. Plot a horizontal bar using `plot.barh` function
# 9. Save the new data

# %%
import matplotlib as plt
data = pd.read_csv('online_retail.csv')
data
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     485345    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     144425    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     485345    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     231216    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 6     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 7     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 8     231216    84406B       CREAM CUPID HEARTS COAT HANGER         8
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# ...

# %%
data = data.dropna()
data
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     485345    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     144425    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     485345    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     231216    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 6     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 8     231216    84406B       CREAM CUPID HEARTS COAT HANGER         8
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-02 08:26:00       3.39     17850.0         Germany
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    8 non-null      int64
#  1   StockCode    8 non-null      str
#  2   Description  8 non-null      str
#  3   Quantity     8 non-null      int64
#  4   InvoiceDate  8 non-null      str
#  5   UnitPrice    8 non-null      float64
#  6   CustomerID   8 non-null      float64
#  7   Country      8 non-null      str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 576.0 bytes

# %%
data.InvoiceDate = pd.to_datetime(data.InvoiceDate)
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 8 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    8 non-null      int64
#  1   StockCode    8 non-null      str
#  2   Description  8 non-null      str
#  3   Quantity     8 non-null      int64
#  4   InvoiceDate  8 non-null      datetime64[us]
#  5   UnitPrice    8 non-null      float64
#  6   CustomerID   8 non-null      float64
#  7   Country      8 non-null      str
# dtypes: datetime64[us](1), float64(2), int64(2), str(3)
# memory usage: 576.0 bytes

# %%
# Count transaction rows per country (each line item is a transaction record)
transactions_per_country = (
    data.groupby('Country')
    .size()
    .sort_values(ascending=False)
    .reset_index(name='TotalTransactions')
)

print(transactions_per_country.head(10))
# Out:
#           Country  TotalTransactions
# 0  United Kingdom                  5
# 1           Spain                  2
# 2         Germany                  1

# %%
transactions_per_country.plot.barh(
    x='Country',
    y='TotalTransactions',
    title='Total Transactions per Country',
    xlabel='Country',
    ylabel='Total Transactions'
)
# Out:
# <Axes: title={'center': 'Total Transactions per Country'}, xlabel='Country', ylabel='Total Transactions'>

# %%
data.to_csv('cleaned_sales_transactions.csv', index=False)

# %% [markdown]
# ### Question 3

# %% [markdown]
# The exercise will involve data cleaning, manipulation, and analysis tasks, including the use of the pivot() and melt() functions in Pandas:
#
# 1. Load the data from the CSV file.
# 2. Perform data cleaning tasks such as handling missing values and data types.
# 3. Create additional columns for TotalPrice and YearMonth from the Timestamp column.
# 4. Aggregate the data to calculate total sales for each store and region.
# 5. Use the pivot() function to create a summary table showing total sales for each ProductName across different regions.
# 6. Use the melt() function to reshape the original data into a long format. The id columns are 'StoreID', 'Region', 'ProductID'
# 7. Save the manipulated data to new CSV files.

# %%
data = pd.read_csv('sales_transactions.csv')
data.info()
data['Timestamp'] = pd.to_datetime(data['Timestamp'])
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StoreID      8 non-null      int64
#  1   Region       8 non-null      str
#  2   ProductID    8 non-null      int64
#  3   ProductName  8 non-null      str
#  4   Quantity     8 non-null      int64
#  5   Price        8 non-null      float64
#  6   CustomerID   8 non-null      int64
#  7   Timestamp    8 non-null      str
# dtypes: float64(1), int64(4), str(3)
# memory usage: 644.0 bytes
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StoreID      8 non-null      int64
#  1   Region       8 non-null      str
#  2   ProductID    8 non-null      int64
#  3   ProductName  8 non-null      str
#  4   Quantity     8 non-null      int64
# ...

# %%
#Create additional columns for TotalPrice and YearMonth from the Timestamp column.
data['TotalPrice'] = data['Quantity'] * data['Price']
data['YearMonth'] = data['Timestamp'].dt.to_period('M')
data
# Out:
#    StoreID Region  ProductID ProductName  Quantity  Price  CustomerID  \
# 0        1   East        101    Widget A        10   5.99        1001
# 1        2   West        102    Widget B         8   7.99        1002
# 2        1   East        103    Widget C        15   6.49        1003
# 3        3  North        101    Widget A        12   5.99        1004
# 4        2   West        104    Widget D         6   9.99        1005
# 5        3  North        102    Widget B        10   7.99        1006
# 6        1   East        105    Widget E        20   8.49        1007
# 7        2   West        103    Widget C        18   6.49        1008
#
#             Timestamp  TotalPrice YearMonth
# 0 2024-01-01 08:00:00       59.90   2024-01
# 1 2024-01-01 09:30:00       63.92   2024-01
# 2 2024-01-01 10:15:00       97.35   2024-01
# 3 2024-01-02 11:20:00       71.88   2024-01
# 4 2024-01-02 12:45:00       59.94   2024-01
# 5 2024-01-03 14:00:00       79.90   2024-01
# ...

# %%
#Aggregate the data to calculate total sales for each store and region.

total_sales = data.groupby(['StoreID', 'Region'])['TotalPrice'].sum()
total_sales
# Out:
# StoreID  Region
# 1        East      327.05
# 2        West      240.68
# 3        North     151.78
# Name: TotalPrice, dtype: float64

# %%
#Use the pivot() function to create a summary table showing total sales for each ProductName across different regions.
pivot_table = data.pivot(index='ProductName', columns='Region', values='TotalPrice').fillna(0)
pivot_table
# Out:
# Region         East  North    West
# ProductName
# Widget A      59.90  71.88    0.00
# Widget B       0.00  79.90   63.92
# Widget C      97.35   0.00  116.82
# Widget D       0.00   0.00   59.94
# Widget E     169.80   0.00    0.00

# %%
#Use the melt() function to reshape the original data into a long format. The id columns are 'StoreID', 'Region', 'ProductID'

melted_data = data.melt(id_vars=['StoreID', 'Region', 'ProductID'], var_name='Variable', value_name='Value')
melted_data
# Save the manipulated data to new CSV files
total_sales.to_csv('total_sales.csv')
pivot_table.to_csv('pivot_table.csv')
melted_data.to_csv('melted_data.csv', index=False)

# %% [markdown]
# ### Question 4

# %% [markdown]
# The Excel file contains two sheets:
#
# Student Scores: Contains columns for StudentID, Name, MathScore, PhysicsScore, ChemistryScore, and BiologyScore. Each row represents a student's scores in different subjects.
# Student Details: Contains additional details about each student, including StudentID, Name, Gender, Age, and Grade.
#
# Task Description:
#
# 1. Load the data from the Student Scores and Student Details sheets in the Excel file.
# 2. Perform data cleaning tasks such as handling missing values and data types.
# 3. Merge the scores data with student details using StudentID as the key.
# 4. Calculate the average score for each student and add it as a new column.
# 5. Use the groupby() function to calculate average scores for each subject.
# 6. Use the pivot_table() function to create a summary table showing average scores for each subject by gender.
# 7. Use the melt() function to reshape the merged data into a long format.
#     * ID columns are = 'StudentID', 'Name', 'Gender', 'Age', 'Grade'.
#     * Melted columns are = 'MathScore', 'PhysicsScore', 'ChemistryScore', 'BiologyScore'
# 9. Save the manipulated data to a new Excel file.

# %%
scores_df = pd.read_excel('student_performance.xlsx', sheet_name='Student Scores')
details_df = pd.read_excel('student_performance.xlsx', sheet_name='Student Details')

# %%
print("Student Scores:")
print(scores_df.head())

print("\nStudent Details:")
print(details_df.head())
# Out:
# Student Scores:
#    StudentID  MathScore  PhysicsScore  ChemistryScore  BiologyScore
# 0          1         66            77              82            81
# 1          2         66            79              71            71
# 2          3         68            90              71            70
# 3          4         89            63              92            62
# 4          5         95            82              91            91
#
# Student Details:
#    StudentID              Name  Gender  Age Grade
# 0          1      Casey Morris  Female   23     B
# 1          2      Jessica Hall  Female   23     B
# 2          3   Jerry Fernandez    Male   23     B
# 3          4  Kathryn Robinson  Female   18     B
# 4          5     Brett Delgado  Female   22     A

# %%
# Check missing values
print("\nMissing values in Student Scores:")
print(scores_df.isnull().sum())

print("\nMissing values in Student Details:")
print(details_df.isnull().sum())
# Out:
# Missing values in Student Scores:
# StudentID         0
# MathScore         0
# PhysicsScore      0
# ChemistryScore    0
# BiologyScore      0
# dtype: int64
#
# Missing values in Student Details:
# StudentID    0
# Name         0
# Gender       0
# Age          0
# Grade        0
# dtype: int64

# %%
print(scores_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StudentID       100 non-null    int64
#  1   MathScore       100 non-null    int64
#  2   PhysicsScore    100 non-null    int64
#  3   ChemistryScore  100 non-null    int64
#  4   BiologyScore    100 non-null    int64
# dtypes: int64(5)
# memory usage: 4.0 KB
# None

# %%
print(details_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  100 non-null    int64
#  1   Name       100 non-null    str
#  2   Gender     100 non-null    str
#  3   Age        100 non-null    int64
#  4   Grade      100 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 4.0 KB
# None

# %%
#Merge the scores data with student details using StudentID as the key.
merged_df = pd.merge(scores_df, details_df, on='StudentID', how='inner')
print(merged_df.head())
# Out:
#    StudentID  MathScore  PhysicsScore  ChemistryScore  BiologyScore  \
# 0          1         66            77              82            81
# 1          2         66            79              71            71
# 2          3         68            90              71            70
# 3          4         89            63              92            62
# 4          5         95            82              91            91
#
#                Name  Gender  Age Grade
# 0      Casey Morris  Female   23     B
# 1      Jessica Hall  Female   23     B
# 2   Jerry Fernandez    Male   23     B
# 3  Kathryn Robinson  Female   18     B
# 4     Brett Delgado  Female   22     A

# %%
#Calculate the average score for each student and add it as a new column
merged_df['AvgScore'] = merged_df[['MathScore', 'PhysicsScore', 'ChemistryScore','BiologyScore']].mean(axis=1)
merged_df
# Out:
#     StudentID  MathScore  PhysicsScore  ChemistryScore  BiologyScore  \
# 0           1         66            77              82            81
# 1           2         66            79              71            71
# 2           3         68            90              71            70
# 3           4         89            63              92            62
# 4           5         95            82              91            91
# ..        ...        ...           ...             ...           ...
# 95         96         66            68              82           100
# 96         97         96            96              65            67
# 97         98         60            67              94            63
# 98         99         63            86              97            95
# 99        100         60            96              89            62
#
#                 Name  Gender  Age Grade  AvgScore
# 0       Casey Morris  Female   23     B     76.50
# ...

# %%
#Use the groupby() function to calculate average scores for each subject.
subject_avg_groupby = merged_df[["MathScore", "PhysicsScore", "ChemistryScore", "BiologyScore"]] \
    .melt(var_name="Subject", value_name="Score") \
    .groupby("Subject", as_index=False)["Score"].mean()

subject_avg_groupby = subject_avg_groupby.rename(columns={"Score": "AverageScore"})

print(subject_avg_groupby)
# Out:
#           Subject  AverageScore
# 0    BiologyScore         81.04
# 1  ChemistryScore         79.95
# 2       MathScore         78.99
# 3    PhysicsScore         79.59

# %%
#Use the pivot_table() function to create a summary table showing average scores for each subject by gender.
pivot_summary = pd.pivot_table(
    merged_df,
    values=['MathScore', 'PhysicsScore', 'ChemistryScore','BiologyScore'],
    index='Gender',
    aggfunc='mean'
)

pivot_summary
# Out:
#         BiologyScore  ChemistryScore  MathScore  PhysicsScore
# Gender
# Female     79.407407       80.703704  79.407407     80.055556
# Male       82.956522       79.065217  78.500000     79.043478

# %%
#Use melt() to reshape the merged data into long format, 
# * ID columns are = 'StudentID', 'Name', 'Gender', 'Age', 'Grade'. 
# Melted columns are = 'MathScore', 'PhysicsScore', 'ChemistryScore', 'BiologyScore'

melted_df = pd.melt(
    merged_df,
    id_vars=['StudentID', 'Name', 'Gender', 'Age', 'Grade'],
    value_vars=['MathScore', 'PhysicsScore', 'ChemistryScore', 'BiologyScore'],
    var_name='Subject',
    value_name='Score'
)

melted_df.head(101)

# %%
with pd.ExcelWriter('student_performance_analysis.xlsx') as writer:
    merged_df.to_excel(writer, sheet_name='MergedData', index=False)
    subject_avg.to_excel(writer, sheet_name='SubjectAverages')
    pivot_summary.to_excel(writer, sheet_name='PivotSummary')
    melted_df.to_excel(writer, sheet_name='MeltedData', index=False)
